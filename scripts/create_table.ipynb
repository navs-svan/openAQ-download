# %% [markdown]
# #### Retrieve environment variables

# %%
import os
from dotenv import find_dotenv, load_dotenv

env_file = find_dotenv(".env")
load_dotenv(env_file)

DBHOST = os.environ.get("DBHOST")
DBPORT = os.environ.get("DBPORT")
DBUSER = os.environ.get("DBUSER")
DBNAME = os.environ.get("DBNAME")
DBPASS = os.environ.get("DBPASS")

# %% [markdown]
# #### Create tables

# %%
from sqlalchemy import URL, create_engine
from sqlalchemy.orm import sessionmaker
from sql.schema import Base, Countries, Locations, Parameters, Sensors
from sqlalchemy.dialects.postgresql import insert

# %%
engine_url = URL.create(
    drivername="postgresql+psycopg2",
    username=DBUSER,
    password=DBPASS,
    host=DBHOST,
    port=DBPORT,
    database=DBNAME,
)
engine = create_engine(url=engine_url)

Base.metadata.create_all(bind=engine)
Session = sessionmaker(bind=engine)
session = Session()

# %% [markdown]
# #### Set up openAQ api app

# %%
import sys
import os

# Get the current working directory (the directory where the notebook is running)
notebook_dir = os.getcwd()

# Construct the path to the 'src' folder
src_dir = os.path.join(notebook_dir, 'src')

# Add 'src' folder to the system path
sys.path.append(src_dir)

from src.openAQ_api import openAQ

app = openAQ()

# %% [markdown]
# #### Populate Parameters Table

# %%
params = app.get_parameters()
params
# Out:
# {'meta': {'name': 'openaq-api',
#   'website': '/',
#   'page': 1,
#   'limit': 100,
#   'found': 38},
#  'results': [{'id': 1,
#    'name': 'pm10',
#    'units': 'µg/m³',
#    'displayName': 'PM10',
#    'description': 'Particulate matter less than 10 micrometers in diameter mass concentration'},
#   {'id': 2,
#    'name': 'pm25',
#    'units': 'µg/m³',
#    'displayName': 'PM2.5',
#    'description': 'Particulate matter less than 2.5 micrometers in diameter mass concentration'},
#   {'id': 3,
#    'name': 'o3',
#    'units': 'µg/m³',
#    'displayName': 'O₃ mass',
#    'description': 'Ozone mass concentration'},
#   {'id': 4,
#    'name': 'co',
#    'units': 'µg/m³',
#    'displayName': 'CO mass',
#    'description': 'Carbon Monoxide mass concentration'},
#   {'id': 5,
#    'name': 'no2',
#    'units': 'µg/m³',
#    'displayName': 'NO₂ mass',
#    'description': 'Nitrogen Dioxide mass concentration'},
#   {'id': 6,
#    'name': 'so2',
#    'units': 'µg/m³',
#    'displayName': 'SO₂ mass',
#    'description': 'Sulfur Dioxide mass concentration'},
#   {'id': 7,
#    'name': 'no2',
#    'units': 'ppm',
#    'displayName': 'NO₂',
#    'description': 'Nitrogen Dioxide concentration'},
#   {'id': 8,
#    'name': 'co',
#    'units': 'ppm',
#    'displayName': 'CO',
#    'description': 'Carbon Monoxide concentration'},
#   {'id': 9,
#    'name': 'so2',
#    'units': 'ppm',
#    'displayName': 'SO₂',
#    'description': 'Sulfur Dioxide concentration'},
#   {'id': 10,
#    'name': 'o3',
#    'units': 'ppm',
#    'displayName': 'O₃',
#    'description': 'Ozone concentration'},
#   {'id': 11,
#    'name': 'bc',
#    'units': 'µg/m³',
#    'displayName': 'BC',
#    'description': 'Black Carbon mass concentration'},
#   {'id': 15,
#    'name': 'no2',
#    'units': 'ppb',
#    'displayName': 'NO₂',
#    'description': None},
#   {'id': 19,
#    'name': 'pm1',
#    'units': 'µg/m³',
#    'displayName': 'PM1',
#    'description': 'Particulate matter less than 1 micrometer in diameter mass concentration'},
#   {'id': 21,
#    'name': 'co2',
#    'units': 'ppm',
#    'displayName': 'CO₂',
#    'description': 'Carbon Dioxide concentration'},
#   {'id': 23,
#    'name': 'nox',
#    'units': 'ppb',
#    'displayName': 'NOX',
#    'description': None},
#   {'id': 24,
#    'name': 'no',
#    'units': 'ppb',
#    'displayName': 'NO',
#    'description': None},
#   {'id': 27,
#    'name': 'nox',
#    'units': 'µg/m³',
#    'displayName': 'NOx mass',
#    'description': 'Nitrogen Oxides mass concentration'},
#   {'id': 28,
#    'name': 'ch4',
#    'units': 'ppm',
#    'displayName': 'CH₄',
#    'description': 'Methane concentration'},
#   {'id': 32,
#    'name': 'o3',
#    'units': 'ppb',
#    'displayName': 'O₃',
#    'description': None},
#   {'id': 33,
#    'name': 'ufp',
#    'units': 'particles/cm³',
#    'displayName': 'UFP count',
#    'description': 'Ultrafine Particles count concentration'},
#   {'id': 35,
#    'name': 'no',
#    'units': 'ppm',
#    'displayName': 'NO',
#    'description': 'Nitrogen Monoxide concentration'},
#   {'id': 95,
#    'name': 'pressure',
#    'units': 'hpa',
#    'displayName': 'Atmospheric pressure',
#    'description': 'Atmospheric or barometric pressure'},
#   {'id': 97,
#    'name': 'pm25-old',
#    'units': 'ugm3',
#    'displayName': None,
#    'description': None},
#   {'id': 98,
#    'name': 'relativehumidity',
#    'units': '%',
#    'displayName': 'RH',
#    'description': None},
#   {'id': 100,
#    'name': 'temperature',
#    'units': 'c',
#    'displayName': 'T',
#    'description': None},
#   {'id': 101,
#    'name': 'so2',
#    'units': 'ppb',
#    'displayName': 'SO₂',
#    'description': None},
#   {'id': 102,
#    'name': 'co',
#    'units': 'ppb',
#    'displayName': 'CO',
#    'description': None},
#   {'id': 125,
#    'name': 'um003',
#    'units': 'particles/cm³',
#    'displayName': 'PM0.3 count',
#    'description': None},
#   {'id': 126,
#    'name': 'um010',
#    'units': 'particles/cm³',
#    'displayName': 'PM1 count',
#    'description': 'PM1 count'},
#   {'id': 128,
#    'name': 'temperature',
#    'units': 'f',
#    'displayName': 'Temperature (F)',
#    'description': None},
#   {'id': 130,
#    'name': 'um025',
#    'units': 'particles/cm³',
#    'displayName': 'PM2.5 count',
#    'description': 'PM2.5 count'},
#   {'id': 132,
#    'name': 'pressure',
#    'units': 'mb',
#    'displayName': 'Pressure',
#    'description': None},
#   {'id': 134,
#    'name': 'humidity',
#    'units': '%',
#    'displayName': 'H',
#    'description': None},
#   {'id': 135,
#    'name': 'um100',
#    'units': 'particles/cm³',
#    'displayName': 'PM10 count',
#    'description': 'PM10 count'},
#   {'id': 19840,
#    'name': 'nox',
#    'units': 'ppm',
#    'displayName': 'NOx',
#    'description': 'Nitrogen Oxides concentration'},
#   {'id': 19843,
#    'name': 'no',
#    'units': 'µg/m³',
#    'displayName': 'NO mass',
#    'description': 'Nitrogen Monoxide mass concentration'},
#   {'id': 19844,
#    'name': 'pm4',
#    'units': 'µg/m³',
#    'displayName': 'PM4.0',
#    'description': 'Particulate matter less than 4 micrometers in diameter mass concentration'},
#   {'id': 19860,
#    'name': 'pm25',
#    'units': 'ppm',
#    'displayName': None,
#    'description': None}]}

# %%
param_list = []

for param in params["results"]:
    param_list.append({
            "parameter_id": param["id"],
            "parameter_name":param["name"],
            "units":param["units"],
            "display_name":param["displayName"],
            "description":param["description"],
        }
    )

# %%
session.execute(insert(Parameters).values(param_list).on_conflict_do_nothing())
session.commit()

# %% [markdown]
# #### Populate Countries Table

# %% [markdown]
# OpenAQ uses the [ISO 3166-1 alpha 2](https://www.iso.org/obp/ui/#search) country codes, which may differ from that reported by the upstream provider. Place the countries of interest inside the `relevant_countries` tuple.

# %%
relevant_countries = ("HK", "SG", "TW", "VN", "TH", "PH", "ID", "MY")

# %%
countries = app.get_countries(limit=200)
countries
# Out:
# {'meta': {'name': 'openaq-api',
#   'website': '/',
#   'page': 1,
#   'limit': 200,
#   'found': 131},
#  'results': [{'id': 1,
#    'code': 'ID',
#    'name': 'Indonesia',
#    'datetimeFirst': '2016-01-30T01:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#     {'id': 11, 'name': 'bc', 'units': 'µg/m³', 'displayName': None},
#     {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 21, 'name': 'co2', 'units': 'ppm', 'displayName': None},
#     {'id': 24, 'name': 'no', 'units': 'ppb', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#     {'id': 130,
#      'name': 'um025',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 2,
#    'code': 'MY',
#    'name': 'Malaysia',
#    'datetimeFirst': '2022-11-03T21:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 3,
#    'code': 'CL',
#    'name': 'Chile',
#    'datetimeFirst': '2016-01-30T01:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 5,
#    'code': 'PE',
#    'name': 'Peru',
#    'datetimeFirst': '2016-03-04T17:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 6,
#    'code': 'AR',
#    'name': 'Argentina',
#    'datetimeFirst': '2016-01-01T03:00:00Z',
#    'datetimeLast': '2024-10-22T03:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 7,
#    'code': '-99',
#    'name': 'Dhekelia',
#    'datetimeFirst': '2023-03-19T01:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 8,
#    'code': 'CY',
#    'name': 'Cyprus',
#    'datetimeFirst': '2020-04-20T16:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 9,
#    'code': 'IN',
#    'name': 'India',
#    'datetimeFirst': '2016-01-30T00:30:00Z',
#    'datetimeLast': '2024-10-21T07:00:57.989Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 10,
#    'code': 'CN',
#    'name': 'China',
#    'datetimeFirst': '2016-01-01T01:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 11,
#    'code': 'IL',
#    'name': 'Israel',
#    'datetimeFirst': '2016-01-01T01:00:00Z',
#    'datetimeLast': '2024-10-21T07:25:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#     {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 23, 'name': 'nox', 'units': 'ppb', 'displayName': None},
#     {'id': 24, 'name': 'no', 'units': 'ppb', 'displayName': None},
#     {'id': 32, 'name': 'o3', 'units': 'ppb', 'displayName': None},
#     {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 101, 'name': 'so2', 'units': 'ppb', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19840, 'name': 'nox', 'units': 'ppm', 'displayName': None}]},
#   {'id': 12,
#    'code': 'PS',
#    'name': 'Palestine',
#    'datetimeFirst': '2017-08-10T23:00:00Z',
#    'datetimeLast': '2024-10-21T07:25:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#     {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#     {'id': 23, 'name': 'nox', 'units': 'ppb', 'displayName': None},
#     {'id': 24, 'name': 'no', 'units': 'ppb', 'displayName': None},
#     {'id': 32, 'name': 'o3', 'units': 'ppb', 'displayName': None},
#     {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#     {'id': 101, 'name': 'so2', 'units': 'ppb', 'displayName': None},
#     {'id': 19840, 'name': 'nox', 'units': 'ppm', 'displayName': None}]},
#   {'id': 14,
#    'code': 'ET',
#    'name': 'Ethiopia',
#    'datetimeFirst': '2016-08-18T23:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None}]},
#   {'id': 15,
#    'code': 'SS',
#    'name': 'South Sudan',
#    'datetimeFirst': '2024-09-13T15:00:00Z',
#    'datetimeLast': '2024-10-02T09:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 17,
#    'code': 'KE',
#    'name': 'Kenya',
#    'datetimeFirst': '2018-04-21T00:00:00Z',
#    'datetimeLast': '2024-10-21T07:06:02.916Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#   {'id': 22,
#    'code': 'FR',
#    'name': 'France',
#    'datetimeFirst': '2016-11-21T11:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 24,
#    'code': 'GY',
#    'name': 'Guyana',
#    'datetimeFirst': '2024-10-02T12:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 25,
#    'code': 'KR',
#    'name': 'Republic of Korea',
#    'datetimeFirst': '2020-10-12T06:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:10.297Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 27,
#    'code': 'MA',
#    'name': 'Morocco',
#    'datetimeFirst': '2024-04-04T10:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 29,
#    'code': 'CR',
#    'name': 'Costa Rica',
#    'datetimeFirst': '2019-10-28T18:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:11.734Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None}]},
#   {'id': 32,
#    'code': 'CD',
#    'name': 'Democratic Republic of the Congo',
#    'datetimeFirst': '2022-06-16T17:00:00Z',
#    'datetimeLast': '2024-10-21T06:00:00Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None}]},
#   {'id': 34,
#    'code': 'UA',
#    'name': 'Ukraine',
#    'datetimeFirst': '2023-09-12T17:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 37,
#    'code': 'ZA',
#    'name': 'South Africa',
#    'datetimeFirst': '2016-02-14T08:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#     {'id': 19840, 'name': 'nox', 'units': 'ppm', 'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 38,
#    'code': 'MF',
#    'name': 'Saint-Martin',
#    'datetimeFirst': '2024-01-28T23:00:00Z',
#    'datetimeLast': '2024-10-21T06:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 40,
#    'code': 'OM',
#    'name': 'Oman',
#    'datetimeFirst': '2022-10-28T16:00:00Z',
#    'datetimeLast': '2024-05-20T14:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 41,
#    'code': 'UZ',
#    'name': 'Uzbekistan',
#    'datetimeFirst': '2018-11-27T22:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]},
#   {'id': 42,
#    'code': 'KZ',
#    'name': 'Kazakhstan',
#    'datetimeFirst': '2018-07-27T17:00:00Z',
#    'datetimeLast': '2024-10-21T07:07:02.625Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 43,
#    'code': 'TJ',
#    'name': 'Tajikistan',
#    'datetimeFirst': '2019-10-20T23:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#   {'id': 44,
#    'code': 'LT',
#    'name': 'Lithuania',
#    'datetimeFirst': '2017-09-21T23:00:00Z',
#    'datetimeLast': '2024-10-21T06:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 45,
#    'code': 'BR',
#    'name': 'Brazil',
#    'datetimeFirst': '2017-07-01T00:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 46,
#    'code': 'UY',
#    'name': 'Uruguay',
#    'datetimeFirst': '2023-10-19T22:00:00Z',
#    'datetimeLast': '2023-10-21T10:00:00Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None}]},
#   {'id': 47,
#    'code': 'MN',
#    'name': 'Mongolia',
#    'datetimeFirst': '2016-01-30T00:15:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 48,
#    'code': 'RU',
#    'name': 'Russian Federation',
#    'datetimeFirst': '2016-11-21T11:00:00Z',
#    'datetimeLast': '2021-08-09T11:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 49,
#    'code': 'CZ',
#    'name': 'Czech Republic',
#    'datetimeFirst': '2016-11-21T11:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 50,
#    'code': 'DE',
#    'name': 'Germany',
#    'datetimeFirst': '2016-11-21T11:00:00Z',
#    'datetimeLast': '2024-10-21T07:02:56.249Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 51,
#    'code': 'EE',
#    'name': 'Estonia',
#    'datetimeFirst': '2020-04-20T20:00:00Z',
#    'datetimeLast': '2024-10-21T06:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 52,
#    'code': 'LV',
#    'name': 'Latvia',
#    'datetimeFirst': '2017-09-22T10:00:00Z',
#    'datetimeLast': '2024-10-21T06:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 53,
#    'code': 'NO',
#    'name': 'Norway',
#    'datetimeFirst': '2016-12-02T10:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 54,
#    'code': 'SE',
#    'name': 'Sweden',
#    'datetimeFirst': '2017-02-08T01:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 55,
#    'code': 'FI',
#    'name': 'Finland',
#    'datetimeFirst': '2016-12-10T19:00:00Z',
#    'datetimeLast': '2024-10-21T06:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 56,
#    'code': 'VN',
#    'name': 'Vietnam',
#    'datetimeFirst': '2016-01-30T01:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None}]},
#   {'id': 58,
#    'code': 'LU',
#    'name': 'Luxembourg',
#    'datetimeFirst': '2017-09-22T10:00:00Z',
#    'datetimeLast': '2024-10-21T06:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 59,
#    'code': 'AE',
#    'name': 'United Arab Emirates',
#    'datetimeFirst': '2019-11-25T17:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 60,
#    'code': 'BE',
#    'name': 'Belgium',
#    'datetimeFirst': '2016-11-17T23:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#   {'id': 62,
#    'code': 'MK',
#    'name': 'North Macedonia',
#    'datetimeFirst': '2016-12-10T20:00:00Z',
#    'datetimeLast': '2024-09-20T09:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 64,
#    'code': 'AZ',
#    'name': 'Azerbaijan',
#    'datetimeFirst': '2022-06-23T13:00:00Z',
#    'datetimeLast': '2024-10-21T06:00:00Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None}]},
#   {'id': 65,
#    'code': 'XK',
#    'name': 'Kosovo',
#    'datetimeFirst': '2016-04-08T20:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 66,
#    'code': 'TR',
#    'name': 'Turkey',
#    'datetimeFirst': '2016-12-12T06:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 67,
#    'code': 'ES',
#    'name': 'Spain',
#    'datetimeFirst': '2016-11-17T23:00:00Z',
#    'datetimeLast': '2024-10-21T07:43:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#     {'id': 95, 'name': 'pressure', 'units': 'hpa', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 134, 'name': 'humidity', 'units': '%', 'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19844, 'name': 'pm4', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 68,
#    'code': 'LA',
#    'name': 'Lao PDR',
#    'datetimeFirst': '2019-06-16T02:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None}]},
#   {'id': 69,
#    'code': 'KG',
#    'name': 'Kyrgyzstan',
#    'datetimeFirst': '2019-03-08T20:00:00Z',
#    'datetimeLast': '2024-10-21T07:06:31.647Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#   {'id': 121,
#    'code': 'MC',
#    'name': 'Monaco',
#    'datetimeFirst': '2023-09-25T16:11:07Z',
#    'datetimeLast': '2023-09-25T16:46:07Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None}]},
#   {'id': 122,
#    'code': 'DZ',
#    'name': 'Algeria',
#    'datetimeFirst': '2019-06-15T22:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None}]},
#   {'id': 123,
#    'code': 'MZ',
#    'name': 'Mozambique',
#    'datetimeFirst': '2024-01-18T19:00:00Z',
#    'datetimeLast': '2024-10-21T06:00:00Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]},
#   {'id': 70,
#    'code': 'AM',
#    'name': 'Armenia',
#    'datetimeFirst': '2022-11-14T09:00:00Z',
#    'datetimeLast': '2024-10-21T07:06:57.8Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None}]},
#   {'id': 71,
#    'code': 'DK',
#    'name': 'Denmark',
#    'datetimeFirst': '2016-11-21T11:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 74,
#    'code': 'RO',
#    'name': 'Romania',
#    'datetimeFirst': '2020-04-19T21:00:00Z',
#    'datetimeLast': '2024-10-21T07:05:50.035Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#   {'id': 75,
#    'code': 'HU',
#    'name': 'Hungary',
#    'datetimeFirst': '2016-12-12T14:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 76,
#    'code': 'SK',
#    'name': 'Slovakia',
#    'datetimeFirst': '2016-11-18T05:00:00Z',
#    'datetimeLast': '2024-10-21T06:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 77,
#    'code': 'PL',
#    'name': 'Poland',
#    'datetimeFirst': '2016-01-30T01:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 11, 'name': 'bc', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 78,
#    'code': 'IE',
#    'name': 'Ireland',
#    'datetimeFirst': '2016-12-10T21:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 79,
#    'code': 'GB',
#    'name': 'United Kingdom',
#    'datetimeFirst': '2016-01-30T01:00:00Z',
#    'datetimeLast': '2024-10-21T07:06:58.749Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 21, 'name': 'co2', 'units': 'ppm', 'displayName': None},
#     {'id': 27, 'name': 'nox', 'units': 'µg/m³', 'displayName': None},
#     {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 80,
#    'code': 'GR',
#    'name': 'Greece',
#    'datetimeFirst': '2020-04-20T18:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 81,
#    'code': 'ZM',
#    'name': 'Zambia',
#    'datetimeFirst': '2024-09-01T17:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
# ...
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 155,
#    'code': 'US',
#    'name': 'United States',
#    'datetimeFirst': '2016-01-30T01:00:00Z',
#    'datetimeLast': '2024-10-21T07:07:06.263Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#     {'id': 11, 'name': 'bc', 'units': 'µg/m³', 'displayName': None},
#     {'id': 15, 'name': 'no2', 'units': 'ppb', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 21, 'name': 'co2', 'units': 'ppm', 'displayName': None},
#     {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#     {'id': 95, 'name': 'pressure', 'units': 'hpa', 'displayName': None},
#     {'id': 97, 'name': 'pm25-old', 'units': 'ugm3', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#     {'id': 19840, 'name': 'nox', 'units': 'ppm', 'displayName': None}]},
#   {'id': 156,
#    'code': 'CA',
#    'name': 'Canada',
#    'datetimeFirst': '2016-03-06T20:00:00Z',
#    'datetimeLast': '2024-10-21T07:06:09.013Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19840, 'name': 'nox', 'units': 'ppm', 'displayName': None}]},
#   {'id': 157,
#    'code': 'MX',
#    'name': 'Mexico',
#    'datetimeFirst': '2016-03-06T20:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19840, 'name': 'nox', 'units': 'ppm', 'displayName': None}]},
#   {'id': 158,
#    'code': 'BZ',
#    'name': 'Belize',
#    'datetimeFirst': '2023-03-19T02:00:00Z',
#    'datetimeLast': '2024-06-25T07:00:00Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None}]},
#   {'id': 162,
#    'code': 'EG',
#    'name': 'Egypt',
#    'datetimeFirst': '2022-06-20T19:00:00Z',
#    'datetimeLast': '2024-10-21T06:00:00Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None}]},
#   {'id': 166,
#    'code': 'GM',
#    'name': 'The Gambia',
#    'datetimeFirst': '2022-10-20T00:13:59.939Z',
#    'datetimeLast': '2023-09-15T23:03:55.489Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None}]},
#   {'id': 167,
#    'code': 'HK',
#    'name': 'Hong Kong',
#    'datetimeFirst': '2018-01-02T22:00:00Z',
#    'datetimeLast': '2024-10-21T06:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 176,
#    'code': 'AQ',
#    'name': 'Antarctica',
#    'datetimeFirst': '2018-11-30T11:00:00Z',
#    'datetimeLast': '2021-02-04T14:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]},
#   {'id': 177,
#    'code': 'AU',
#    'name': 'Australia',
#    'datetimeFirst': '2016-01-28T19:00:00Z',
#    'datetimeLast': '2024-10-21T12:44:08Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 128, 'name': 'temperature', 'units': 'f', 'displayName': None},
#     {'id': 19860, 'name': 'pm25', 'units': 'ppm', 'displayName': None}]},
#   {'id': 180,
#    'code': 'NZ',
#    'name': 'New Zealand',
#    'datetimeFirst': '2023-03-30T17:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 182,
#    'code': 'MG',
#    'name': 'Madagascar',
#    'datetimeFirst': '2020-12-22T07:00:00Z',
#    'datetimeLast': '2024-10-21T06:00:00Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None}]},
#   {'id': 183,
#    'code': 'PH',
#    'name': 'Philippines',
#    'datetimeFirst': '2023-09-06T21:00:00Z',
#    'datetimeLast': '2024-10-21T07:01:16.985Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 184,
#    'code': 'LK',
#    'name': 'Sri Lanka',
#    'datetimeFirst': '2017-09-26T00:00:00Z',
#    'datetimeLast': '2024-10-21T06:56:38.398Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None}]},
#   {'id': 185,
#    'code': 'CW',
#    'name': 'Curaçao',
#    'datetimeFirst': '2018-07-27T16:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]},
#   {'id': 189,
#    'code': 'TW',
#    'name': 'Taiwan',
#    'datetimeFirst': '2016-12-20T19:00:00Z',
#    'datetimeLast': '2024-10-21T07:03:07.499Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 190,
#    'code': 'JP',
#    'name': 'Japan',
#    'datetimeFirst': '2023-07-14T17:00:00Z',
#    'datetimeLast': '2024-10-21T07:05:59.649Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 7, 'name': 'no2', 'units': 'ppm', 'displayName': None},
#     {'id': 8, 'name': 'co', 'units': 'ppm', 'displayName': None},
#     {'id': 9, 'name': 'so2', 'units': 'ppm', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 35, 'name': 'no', 'units': 'ppm', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None},
#     {'id': 19840, 'name': 'nox', 'units': 'ppm', 'displayName': None}]},
#   {'id': 192,
#    'code': 'IS',
#    'name': 'Iceland',
#    'datetimeFirst': '2020-02-28T01:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 211,
#    'code': 'PR',
#    'name': 'Puerto Rico',
#    'datetimeFirst': '2016-05-04T12:00:00Z',
#    'datetimeLast': '2024-10-15T11:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]},
#   {'id': 219,
#    'code': 'MU',
#    'name': 'Mauritius',
#    'datetimeFirst': '2023-11-05T03:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 222,
#    'code': 'CV',
#    'name': 'Republic of Cabo Verde',
#    'datetimeFirst': '2024-04-24T15:07:35.089Z',
#    'datetimeLast': '2024-10-21T06:57:32.629Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None}]},
#   {'id': 223,
#    'code': 'MT',
#    'name': 'Malta',
#    'datetimeFirst': '2017-09-22T10:00:00Z',
#    'datetimeLast': '2024-10-21T06:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 3, 'name': 'o3', 'units': 'µg/m³', 'displayName': None},
#     {'id': 4, 'name': 'co', 'units': 'µg/m³', 'displayName': None},
#     {'id': 5, 'name': 'no2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 6, 'name': 'so2', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19843, 'name': 'no', 'units': 'µg/m³', 'displayName': None}]},
#   {'id': 224,
#    'code': 'JE',
#    'name': 'Jersey',
#    'datetimeFirst': '2024-06-10T14:00:00Z',
#    'datetimeLast': '2024-10-21T07:04:05.649Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None}]},
#   {'id': 231,
#    'code': 'SG',
#    'name': 'Singapore',
#    'datetimeFirst': '2016-04-05T09:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:16.865Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 239,
#    'code': 'MV',
#    'name': 'Maldives',
#    'datetimeFirst': '2024-09-08T19:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 1,
#      'name': 'pm10',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 2, 'name': 'pm25', 'units': 'µg/m³', 'displayName': None},
#     {'id': 19, 'name': 'pm1', 'units': 'µg/m³', 'displayName': None},
#     {'id': 98, 'name': 'relativehumidity', 'units': '%', 'displayName': None},
#     {'id': 100, 'name': 'temperature', 'units': 'c', 'displayName': None},
#     {'id': 125,
#      'name': 'um003',
#      'units': 'particles/cm³',
#      'displayName': None}]},
#   {'id': 250,
#    'code': 'BH',
#    'name': 'Bahrain',
#    'datetimeFirst': '2016-12-01T22:00:00Z',
#    'datetimeLast': '2024-10-21T07:00:00Z',
#    'parameters': [{'id': 2,
#      'name': 'pm25',
#      'units': 'µg/m³',
#      'displayName': None},
#     {'id': 10, 'name': 'o3', 'units': 'ppm', 'displayName': None}]}]}

# %%
country_list = []

for country in countries["results"]:
    if country["code"] in relevant_countries:
        country_list.append({
            "country_id": country["id"],
            "country_name": country["name"],
            "first_date": country["datetimeFirst"],
            "last_date": country["datetimeFirst"],
        })

# %%
session.execute(insert(Countries).values(country_list).on_conflict_do_nothing())
session.commit()

# %% [markdown]
# #### Populate Locations Table

# %%
country_ids = [country["country_id"] for country in country_list]
country_ids
# Out:
# [1, 2, 56, 111, 167, 183, 189, 231]

# %%
def handle_date(datetime):
    if datetime:
        return datetime["utc"]
    else:
        return None

def get_locations(country_ids: list, app: openAQ):
    page = 1

    while True:
        locations = app.get_locations(countries_id=country_ids, limit=1000, page=page)
        print(len(locations["results"]))
        try:
            for location in locations["results"]:
                yield {
                    "location_id": location["id"],
                    "location_name": location["name"],
                    "latitude": location["coordinates"]["latitude"],
                    "longitude": location["coordinates"]["longitude"],
                    "first_date": handle_date(location["datetimeFirst"]),
                    "last_date": handle_date(location["datetimeLast"]),
                    "country_id": location["country"]["id"],
                }
            if locations["meta"]["limit"] <= locations["meta"]["found"]:
                page += 1
            else: 
                break
        except TypeError:
            page += 1
            continue

# %%
locations_list = []
locations_list = [detail for detail in get_locations(country_ids=country_ids, app=app)]
len(locations_list)
# Out:
# 719
# 719

# %%
session.execute(insert(Locations).values(locations_list).on_conflict_do_nothing())
session.commit()

# %% [markdown]
# #### Populate Sensors Table

# %%
country_ids
# Out:
# [1, 2, 56, 111, 167, 183, 189, 231]

# %%
# Just a repeat of an earlier function but with different output
def get_sensors(country_ids: list, app: openAQ):
    page = 1

    while True:
        locations = app.get_locations(countries_id=country_ids, limit=1000, page=page)
        try:
            for location in locations["results"]:
                for sensor in location["sensors"]:
                    yield {
                        "sensor_id": sensor["id"],
                        "parameter_id": sensor["parameter"]["id"]
                    }
            if locations["meta"]["limit"] <= locations["meta"]["found"]:
                page += 1
            else: 
                break
        except TypeError:
            page += 1
            continue

# %%
sensor_list = [sensor_detail for sensor_detail in get_sensors(country_ids=country_ids, app=app)]
len(sensor_list)
# Out:
# 3284

# %%
session.execute(insert(Sensors).values(sensor_list).on_conflict_do_nothing())
session.commit()
